# %%
# %%time
# %run parser_main_app.py
# Out:
# TEST MODE
# db engine created
# STAGE 1: parse all codes
# save to db all code...
# codes saved
# STAGE 2: parse codes pages
# parse codes pages...
# 1 0742
# 2 0780
# 3 5999
# save to db codes description...
# codes description saved
# STAGE 3: parse companies
# parse search pages...
# 0 https://mcc-codes.ru/search?extended=true&o=&m=0742&q=&c=&a=
# 1 https://mcc-codes.ru/search?extended=true&o=&m=0780&q=&c=&a=
# 2 https://mcc-codes.ru/search?extended=true&o=&m=5999&q=&c=&a=
# 37
# 2 https://mcc-codes.ru/search?extended=1&m=5999&sortBy=date&sortDir=desc&page=1
# 36
# 3 https://mcc-codes.ru/search?extended=1&m=5999&sortBy=date&sortDir=desc&page=2
# 35
# 4 https://mcc-codes.ru/search?extended=1&m=5999&sortBy=date&sortDir=desc&page=3
# 34
# 5 https://mcc-codes.ru/search?extended=1&m=5999&sortBy=date&sortDir=desc&page=4
# 33
# 6 https://mcc-codes.ru/search?extended=1&m=5999&sortBy=date&sortDir=desc&page=5
# 32
# ...

# %%
import pandas as pd
from models.db import engine

# %%
engine.table_names()
# Out:
# ['company_info', 'all_mcc', 'mcc_desc']

# %%
pd.read_sql("SELECT * FROM company_info", con=engine)
# Out:
#                  id   MCC                                       company_name  \
# 0     0_0742_page_1  0742                Ветеринарная клиника Доктор Айболит
# 1     1_0742_page_1  0742                      Ветеринарная клиника Адельвет
# 2     2_0742_page_1  0742                 Ветеринарный центр в Текстильщиках
# 3     3_0742_page_1  0742   Городская станция по борьбе с болезнями животных
# 4     4_0742_page_1  0742                  Ветеринарная клиника "Арс Медика"
# ..              ...   ...                                                ...
# 743  15_5999_page_9  5999                                 Салюты, фейерверки
# 744  16_5999_page_9  5999               Фирменный магазин при заводе Очаково
# 745  17_5999_page_9  5999  Всероссийский музей Пушкина (усадьба Державина...
# 746  18_5999_page_9  5999        ИП Нестерчук Алла Борисовна Галерея времени
# 747  19_5999_page_9  5999                                           Леонардо
#
# ...

# %%
pd.read_sql("SELECT * FROM all_mcc", con=engine)
# Out:
#        MCC                                          mcc_group  \
# 0     0742                                Ветеринарные услуги
# 1     0763                   Сельскохозяйственные кооперативы
# 2     0780          Услуги садоводства и ландшафтного дизайна
# 3     1520  Генеральные подрядчики – жилое и коммерческое ...
# 4     1711  Генеральные подрядчики по вентиляции, теплосна...
# ...    ...                                                ...
# 1024  9751  Великобритания. Универсамы. Электронный Горячи...
# 1025  9752  Британские Бензозаправочные станции. Электронн...
# 1026  9754              Лошадиные / собачьи бега (только США)
# 1027  9950                            Покупки внутри компании
# 1028  9999                               Категория неизвестна
#
#                          mcc_update_date
# 0                     Контрактные услуги
# 1                     Контрактные услуги
# 2                     Контрактные услуги
# 3                     Контрактные услуги
# ...

# %%
pd.read_sql("SELECT * FROM mcc_desc", con=engine)
# Out:
#     MCC                          category_name_eng  \
# 0  0742                        Veterinary Services
# 1  0780     Horticultural and Landscaping Services
# 2  5999  Miscellaneous and Specialty Retail Stores
#
#                                      mcc_description  amount_marketplacements
# 0  Лицензированные специалисты в основном занимаю...                       20
# 1  Ландшафтные архитекторы и другие поставщики ус...                        6
# 2  Розничные торговые точки, которые продают уник...                      721
